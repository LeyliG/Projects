# %% [markdown]
# # Project: Phone Selection with Data Envelopment Analysis
#
# Data obtained from the following resource (code was not included): https://vc.bridgew.edu/cgi/viewcontent.cgi?article=1355&context=undergrad_rev

# %%
# Load the packages
#!pip install pulp 
import pulp
import numpy as np
import pandas as pd

# load the dataset
df = pd.read_csv('data_phone_selection.csv')

# Define inputs and outputs
inputs = df[['baterry_mah', 'weight_oz', 'camera_mp', 'standby_time_hours']].values
outputs = df['retail_price_usd'].values

# Calculate efficiencies of each DMU using DEA with linear programming
efficiencies = []
num_inputs = inputs.shape[1]


for di in range(len(inputs)):
    prob = pulp.LpProblem("DEA", pulp.LpMaximize)
    w_in = pulp.LpVariable.dicts("w_in", range(num_inputs), lowBound=0)
    w_out = pulp.LpVariable("w_out", lowBound=0)
    
    prob += w_out * outputs[di] - sum(w_in[i] * inputs[di][i] for i in range(num_inputs))
    
    # Add constraints to ensure no DMU's efficiency exceeds 1
    for i in range(len(inputs)):
        prob += w_out * outputs[i] - sum(w_in[j] * inputs[i][j] for j in range(num_inputs)) <= 1
    
    prob.solve()
    
    if prob.status == pulp.LpStatusOptimal:
        efficiencies.append(min(pulp.value(prob.objective), 1))
    else:
        efficiencies.append(None)

# Display efficiencies
for i, eff in enumerate(efficiencies):
    print(f"Efficiency of DMU {i + 1}: {eff}")

# Optional: Add efficiencies to the dataframe and save to a new CSV
df['efficiency'] = efficiencies
#df.to_csv('data_phone_selection_with_efficiencies.csv', index=False)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/c95c9eb2ef514ba5946b9f342c13361c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/c95c9eb2ef514ba5946b9f342c13361c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1476.0082 (1)
# 0  Obj -0 Dual inf 1476.0082 (1)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/09e6ae511bdf4fc984550da9226ca6d6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/09e6ae511bdf4fc984550da9226ca6d6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1640.0137 (1)
# 0  Obj -0 Dual inf 1640.0137 (1)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/acac40aa2e8c4fe5b79111e037a35e60-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/acac40aa2e8c4fe5b79111e037a35e60-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1230 (1)
# 0  Obj -0 Dual inf 1230 (1)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/35d7e81c6618427c8bafc787da4f5bca-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/35d7e81c6618427c8bafc787da4f5bca-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 2050.0273 (1)
# 0  Obj -0 Dual inf 2050.0273 (1)
# 1  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/2fbcd548802b4e8986ca7fddf3f73051-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/2fbcd548802b4e8986ca7fddf3f73051-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1640.0137 (1)
# 0  Obj -0 Dual inf 1640.0137 (1)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/a4111c0de1ab4d91a1f36860a4ddd3cc-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/a4111c0de1ab4d91a1f36860a4ddd3cc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 614.9795 (1)
# 0  Obj -0 Dual inf 614.9795 (1)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/ff81dbb8113f4fb39a2904dcd96df894-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/ff81dbb8113f4fb39a2904dcd96df894-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 614.9795 (1)
# 0  Obj -0 Dual inf 614.9795 (1)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/4f324aef1c3942ac9d1019196c197f30-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/4f324aef1c3942ac9d1019196c197f30-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1640.0137 (1)
# 0  Obj -0 Dual inf 1640.0137 (1)
# 2  Obj 0.94166424
# Optimal - objective value 0.94166424
# Optimal objective 0.941664236 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Efficiency of DMU 1: 0.999999976493
# Efficiency of DMU 2: 1
# Efficiency of DMU 3: 0.999999994375
# Efficiency of DMU 4: 0.9999999996
# Efficiency of DMU 5: 1
# Efficiency of DMU 6: 0.999999960934019
# Efficiency of DMU 7: 0.9999999616600003
# Efficiency of DMU 8: 0.9416642393970002

# %%
df
# Out:
#      decision_making_unit  baterry_mah  weight_oz  camera_mp  \
# 0                iPhone 5         1800       3.95        8.0
# 1           HTC Windows 8         1800       4.60        8.0
# 2              HTC Desire         1230       5.15        5.0
# 3       Samsung Galaxy S4         2600       4.59       13.0
# 4  Samsung Galaxy S4 Mini         1900       3.77        8.0
# 5         Samsung Gusto 3         1000       3.50        1.3
# 6               LG Cosmos          950       4.58        1.3
# 7         Nokia Lumia 928         2000       5.75        8.7
#
#    standby_time_hours  retail_price_usd  efficiency
# 0               225.0            359.99    1.000000
# 1               300.0            399.99    1.000000
# 2               384.0            299.99    1.000000
# 3               370.0            499.99    1.000000
# 4               300.0            399.99    1.000000
# 5               770.4            149.99    1.000000
# 6               818.0            149.99    1.000000
# 7               606.0            399.99    0.941664

# %% [markdown]
# Convert into function to customize the data, inputs and outputs variables, and option to download

# %%
# Function to calculate the efficiencies using Data Envelopment Analysis
# works for multiple inputs and outputs to make the calculations
import pandas as pd
import numpy as np
import pulp

def calculate_efficiencies(data_path, input_features, output_features, output_path=None):
    # Load the dataset
    df = pd.read_csv(data_path)
    
    # Define inputs and outputs
    inputs = df[input_features].values
    outputs = df[output_features].values
    
    # Calculate efficiencies of each DMU using DEA with linear programming
    efficiencies = []
    num_inputs = inputs.shape[1]
    num_outputs = outputs.shape[1]
    
    for di in range(len(inputs)):
        prob = pulp.LpProblem("DEA", pulp.LpMaximize)
        w_in = pulp.LpVariable.dicts("w_in", range(num_inputs), lowBound=0)
        w_out = pulp.LpVariable.dicts("w_out", range(num_outputs), lowBound=0)
        
        # Objective function
        prob += pulp.lpSum([w_out[o] * outputs[di][o] for o in range(num_outputs)]) - \
                pulp.lpSum([w_in[i] * inputs[di][i] for i in range(num_inputs)])
        
        # Add constraints to ensure no DMU's efficiency exceeds 1
        for i in range(len(inputs)):
            prob += pulp.lpSum([w_out[o] * outputs[i][o] for o in range(num_outputs)]) - \
                    pulp.lpSum([w_in[j] * inputs[i][j] for j in range(num_inputs)]) <= 1
        
        prob.solve()
        
        if prob.status == pulp.LpStatusOptimal:
            efficiencies.append(min(pulp.value(prob.objective), 1))
        else:
            efficiencies.append(None)
    
    # Display efficiencies
    for i, eff in enumerate(efficiencies):
        print(f"Efficiency of DMU {i + 1}: {eff}")
    
    # Optional: Add efficiencies to the dataframe and save to a new CSV
    df['efficiency'] = efficiencies
    
    if output_path:
        df.to_csv(output_path, index=False)
    
    return df

# %%
# Example usage:
data_path = 'data_phone_selection.csv'
input_features = ['baterry_mah', 'weight_oz', 'camera_mp', 'standby_time_hours']
output_feature = 'retail_price_usd'
#output_path = 'data_phone_selection_with_efficiencies.csv'

df_with_efficiencies = calculate_efficiencies(data_path, input_features, output_feature)
df_with_efficiencies
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/3330653529c04b98ad1109491ae2f172-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/3330653529c04b98ad1109491ae2f172-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1476.0082 (1)
# 0  Obj -0 Dual inf 1476.0082 (1)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/3fd27fe3cc4540129793cfa3ba2ede11-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/3fd27fe3cc4540129793cfa3ba2ede11-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1640.0137 (1)
# 0  Obj -0 Dual inf 1640.0137 (1)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/eafec414bb3c4928a607384ed36f02ba-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/eafec414bb3c4928a607384ed36f02ba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1230 (1)
# 0  Obj -0 Dual inf 1230 (1)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/655db44dafae4d7c95e2fad0842a55d4-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/655db44dafae4d7c95e2fad0842a55d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 2050.0273 (1)
# 0  Obj -0 Dual inf 2050.0273 (1)
# 1  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/f5b5466fb21c42e397e4bd9b013bd462-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/f5b5466fb21c42e397e4bd9b013bd462-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1640.0137 (1)
# 0  Obj -0 Dual inf 1640.0137 (1)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/c8521e19954c478da00db5a960dd9088-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/c8521e19954c478da00db5a960dd9088-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 614.9795 (1)
# 0  Obj -0 Dual inf 614.9795 (1)
# 5  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/79bfde359ad348708a87e22befd313e6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/79bfde359ad348708a87e22befd313e6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 614.9795 (1)
# 0  Obj -0 Dual inf 614.9795 (1)
# 4  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/5a528feaa8914f04a5748d28b9405304-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/5a528feaa8914f04a5748d28b9405304-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 1640.0137 (1)
# 0  Obj -0 Dual inf 1640.0137 (1)
# 2  Obj 0.94166424
# Optimal - objective value 0.94166424
# Optimal objective 0.941664236 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Efficiency of DMU 1: 0.999999976493
# Efficiency of DMU 2: 1
# Efficiency of DMU 3: 0.999999994375
# Efficiency of DMU 4: 0.9999999996
# Efficiency of DMU 5: 1
# Efficiency of DMU 6: 0.999999960934019
# Efficiency of DMU 7: 0.9999999616600003
# Efficiency of DMU 8: 0.9416642393970002
#      decision_making_unit  baterry_mah  weight_oz  camera_mp  \
# 0                iPhone 5         1800       3.95        8.0
# 1           HTC Windows 8         1800       4.60        8.0
# 2              HTC Desire         1230       5.15        5.0
# 3       Samsung Galaxy S4         2600       4.59       13.0
# 4  Samsung Galaxy S4 Mini         1900       3.77        8.0
# 5         Samsung Gusto 3         1000       3.50        1.3
# 6               LG Cosmos          950       4.58        1.3
# 7         Nokia Lumia 928         2000       5.75        8.7
#
#    standby_time_hours  retail_price_usd  efficiency
# 0               225.0            359.99    1.000000
# 1               300.0            399.99    1.000000
# 2               384.0            299.99    1.000000
# 3               370.0            499.99    1.000000
# 4               300.0            399.99    1.000000
# 5               770.4            149.99    1.000000
# 6               818.0            149.99    1.000000
# 7               606.0            399.99    0.941664

# %%
# Example usage:
data_path = 'data_phone_selection.csv'
input_features = ['baterry_mah', 'weight_oz', 'standby_time_hours']
output_feature = ['retail_price_usd',  'camera_mp']
#output_path = 'data_phone_selection_with_efficiencies.csv'

df_with_efficiencies = calculate_efficiencies(data_path, input_features, output_feature)
df_with_efficiencies
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/f8327ed6f71b4bf49e611e72c34c17ff-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/f8327ed6f71b4bf49e611e72c34c17ff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 3076.0082 (2)
# 0  Obj -0 Dual inf 3076.0082 (2)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/ce3988bfecda48c9888000ec00af303f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/ce3988bfecda48c9888000ec00af303f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 3240.0137 (2)
# 0  Obj -0 Dual inf 3240.0137 (2)
# 2  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/0291e4ba14594fbdaececdb60623ca0c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/0291e4ba14594fbdaececdb60623ca0c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 2230 (2)
# 0  Obj -0 Dual inf 2230 (2)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/ef1cb8aedf4543b5858b83a28e315ca4-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/ef1cb8aedf4543b5858b83a28e315ca4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 4650.0273 (2)
# 0  Obj -0 Dual inf 4650.0273 (2)
# 1  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/1090ba0fe3124e31958c8082fa3826bb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/1090ba0fe3124e31958c8082fa3826bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 3240.0137 (2)
# 0  Obj -0 Dual inf 3240.0137 (2)
# 3  Obj 1
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/62aa3092653e48c2a54fabd3881ba996-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/62aa3092653e48c2a54fabd3881ba996-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 874.9795 (2)
# 0  Obj -0 Dual inf 874.9795 (2)
# 1  Obj 0.299986
# Optimal - objective value 0.299986
# Optimal objective 0.2999859997 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/e1889e6a4a814993903631ea67cbcea1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/e1889e6a4a814993903631ea67cbcea1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 874.9795 (2)
# 0  Obj -0 Dual inf 874.9795 (2)
# 1  Obj 0.299986
# Optimal - objective value 0.299986
# Optimal objective 0.2999859997 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/9d8d7f000f32471fb204eb2211845882-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/8j/3pr9zqy97g998nn_l0_dmlz80000gn/T/9d8d7f000f32471fb204eb2211845882-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 59 RHS
# At line 68 BOUNDS
# At line 69 ENDATA
# Problem MODEL has 8 rows, 5 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 5 (0) columns and 40 (0) elements
# 0  Obj -0 Dual inf 3380.0137 (2)
# 0  Obj -0 Dual inf 3380.0137 (2)
# 3  Obj 0.85713469
# Optimal - objective value 0.85713469
# Optimal objective 0.8571346934 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Efficiency of DMU 1: 0.999999992784
# Efficiency of DMU 2: 1
# Efficiency of DMU 3: 0.9999998519000002
# Efficiency of DMU 4: 1
# Efficiency of DMU 5: 0.9999999760039997
# Efficiency of DMU 6: 0.2999859996
# Efficiency of DMU 7: 0.2999859996
# Efficiency of DMU 8: 0.8571347138769998
#      decision_making_unit  baterry_mah  weight_oz  camera_mp  \
# 0                iPhone 5         1800       3.95        8.0
# 1           HTC Windows 8         1800       4.60        8.0
# 2              HTC Desire         1230       5.15        5.0
# 3       Samsung Galaxy S4         2600       4.59       13.0
# 4  Samsung Galaxy S4 Mini         1900       3.77        8.0
# 5         Samsung Gusto 3         1000       3.50        1.3
# 6               LG Cosmos          950       4.58        1.3
# 7         Nokia Lumia 928         2000       5.75        8.7
#
#    standby_time_hours  retail_price_usd  efficiency
# 0               225.0            359.99    1.000000
# 1               300.0            399.99    1.000000
# 2               384.0            299.99    1.000000
# 3               370.0            499.99    1.000000
# 4               300.0            399.99    1.000000
# 5               770.4            149.99    0.299986
# 6               818.0            149.99    0.299986
# 7               606.0            399.99    0.857135
